# %%
# region day 2
# subscripting
print("hello"[4])

# integer = whole number
print(123 + 345)

# float = floating point number
print(3.13453)

# boolean


# type functiom
print(type("hello"))
print(type(123))
print(type(12.34))
print(type(True))
